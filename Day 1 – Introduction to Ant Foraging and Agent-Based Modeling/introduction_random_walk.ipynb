# %%
# %load_ext autoreload
# %autoreload 2

# %%
import mesa
import matplotlib.pylab as plt
import numpy as np

# %%
from model import AntModel

# %%
dim = 1
m1 = AntModel(width=dim, height=dim, N=1, mean_free_path=0.01, g=0.7, seed=42)

# %%
n_steps = 400
for i in range(n_steps):
    m1.step()

# %%
results = m1.datacollector.get_agent_vars_dataframe()

# %%
results
# Out:
#                      x         y    heading
# Step AgentID
# 1    1        0.500162  0.500195   0.713674
# 2    1        0.510244  0.508924   1.327803
# 3    1        0.510462  0.509807   1.054046
# 4    1        0.511681  0.511952   0.698897
# 5    1        0.513379  0.513379   1.259455
# ...                ...       ...        ...
# 396  1        0.822944  0.282506  18.889788
# 397  1        0.831456  0.282849  18.199554
# 398  1        0.832430  0.282108  18.187987
# 399  1        0.845181  0.272180  18.693032
# 400  1        0.870102  0.268247  18.742196
#
# [400 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 6)) 

ax.plot(results.x, results.y, lw=1, color='0.7')
sc = ax.scatter(results.x, results.y, c=results.index.get_level_values('Step'), cmap='viridis', s=3)
cbar = fig.colorbar(sc, ax=ax, label='Step', shrink=0.8, fraction=0.045)
plt.axis('square')
plt.show()
